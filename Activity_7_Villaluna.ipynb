# %%
# Activity 7 – Data Visualization (Final Output Preview)

## Project Overview
This project uses Python data visualization libraries such as Pandas, Matplotlib, and Seaborn to analyze the Spotify Top 1000 Songs dataset. Different charts and plots were generated to explore patterns in popularity, duration, release years, artists, and albums.

The program demonstrates:
- Data preprocessing and cleaning
- Feature engineering
- Static visualizations
- Animated visualizations
- Trend analysis using charts and graphs

---

# Expected Final Output

After running the code successfully, the following outputs will appear:

## 1. Histogram of Song Duration
Displays the frequency distribution of song durations.

Output:
- Bars representing how many songs fall within certain duration ranges.
- Most songs cluster around average duration values.

---

## 2. Boxplot of Popularity by Decade
Shows how song popularity varies across decades.

Output:
- Median popularity values
- Quartiles and outliers
- Comparison between decades

---

## 3. Top 10 Artists Countplot
Displays artists with the highest number of songs.

Output:
- Horizontal bars ranked by frequency
- Easy comparison of artist dominance

---

## 4. Violin Plot by Decade
Shows duration distribution for each decade.

Output:
- Density shape of durations
- Spread and concentration of values

---

## 5. Average Popularity Line Graph
Displays trend of popularity over decades.

Output:
- Line graph with markers
- Trend increases/decreases over time

---

## 6. Area Plot of Songs Released Per Year
Shows yearly song release trends.

Output:
- Filled area graph
- Growth and decline patterns over time

---

## 7. Scatterplot Facet Grid
Compares duration vs popularity grouped by decade.

Output:
- Multiple scatterplots
- Relationship visualization per decade

---

## 8. Lollipop Chart – Longest Songs
Shows the top 10 longest tracks.

Output:
- Stem-style graph
- Easy ranking of song durations

---

## 9. Dot Plot – Average Duration by Artist
Compares average song duration of artists.

Output:
- Dot comparison chart
- Highlights longer average track creators

---

## 10. Stacked Bar Chart – Top Artists by Decade
Shows artist contributions across decades.

Output:
- Stacked colored bars
- Distribution of songs by decade

---

## 11. Top 10 Tracks by Popularity
Displays the most popular songs.

Output:
- Horizontal ranking bars
- Popularity comparison

---

## 12. Strip Plot – Duration of Top Artists
Shows spread of durations for top artists.

Output:
- Individual duration points
- Variation among artists

---

## 13. Pie Chart – Top Albums Distribution
Shows percentage share of top albums.

Output:
- Pie slices with percentages
- Album contribution visualization

---

## 14. Clustered Heatmap
Displays correlation between numerical features.

Output:
- Annotated heatmap
- Correlation intensity visualization

---

## 15. Pair Plot of Key Attributes
Shows relationships among duration, popularity, and release year.

Output:
- Multiple scatterplots and distributions
- Relationship analysis between variables

---

## 16. Bar Plot – Songs Released Per Year
Displays yearly release count.

Output:
- Vertical bars by year
- Comparison of yearly releases

---

## 17. Swarm Plot – Artist Popularity
Shows popularity distribution per artist.

Output:
- Clustered swarm points
- Spread of popularity values

---

## 18. Hexbin Plot – Duration vs Popularity
Displays density concentration of songs.

Output:
- Hexagonal density bins
- High-density regions highlighted

---

## 19. ECDF Plot – Song Duration
Shows cumulative probability distribution.

Output:
- Smooth increasing curve
- Cumulative distribution of durations

---

## 20. Grouped Bar Chart – Popularity by Artist and Decade
Compares average popularity across decades.

Output:
- Grouped bars for artists
- Decade-based popularity comparison

---

# Animated Visualization Output

## Evolution of Average Popularity Over Time
The program also generates an animated GIF.

Output:
- Animated line graph
- Popularity trend over years
- Automatically saved as:

```text
yearly_popularity_trend.gif
```

---

# Files to Upload on GitHub

Recommended project structure:

```text
Activity7-DataVisualization/
│
├── spotify_top_1000_tracks.csv
├── activity7.ipynb
├── yearly_popularity_trend.gif
├── README.md
└── screenshots/
    ├── histogram.png
    ├── boxplot.png
    ├── scatterplot.png
    └── heatmap.png
```

---

# Suggested GitHub README Description

## Data Visualization using Python

This project analyzes the Spotify Top 1000 Songs dataset using Python visualization libraries such as Matplotlib and Seaborn. Multiple charts, graphs, and animated visualizations were created to explore trends in popularity, duration, release year, artists, and albums.

### Technologies Used
- Python
- Pandas
- NumPy
- Matplotlib
- Seaborn
- Jupyter Notebook

### Features
- Histogram
- Boxplot
- Scatter Plot
- Pair Plot
- Heatmap
- Hexbin Plot
- Animated Line Graph

### Dataset
Spotify Top 1000 Most Played Songs Dataset from Kaggle.

---

# Final Result

After completing the activity, the project produces multiple professional data visualizations and one animated GIF that can be uploaded to GitHub as a complete Python data analysis portfol
